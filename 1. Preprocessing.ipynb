# %% [markdown]
# # 1.Preprocessing - Linear Regression project
#
# ### Notebook objective: clean both datasets in preparation for exploration
#
# Datasets created from this notebook will be named with a leading 1 corresponding to this notebook.

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import os
import re
import fastparquet

# %%
cars = pd.read_csv('car_log.csv', na_values = '*')
people = pd.read_csv('ppl.csv')
display(cars[:4])
display(people[:4])
# Out:
#                     Vehicle Name  Small/Sporty/ Compact/Large Sedan  \
# 0               Acura 3.5 RL 4dr                                  1
# 1  Acura 3.5 RL w/Navigation 4dr                                  1
# 2                      Acura MDX                                  0
# 3   Acura NSX coupe 2dr manual S                                  0
#
#    Sports Car  SUV  Wagon  Minivan  Pickup  AWD  RWD  Retail Price  \
# 0           0    0      0        0       0    0    0         43755
# 1           0    0      0        0       0    0    0         46100
# 2           0    1      0        0       0    1    0         36945
# 3           1    0      0        0       0    0    1         89765
#
#    Dealer Cost  Engine Size (l)  Cyl   HP  City MPG  Hwy MPG  Weight  \
# 0        39014              3.5    6  225      18.0     24.0  3880.0
# 1        41100              3.5    6  225      18.0     24.0  3893.0
# 2        33337              3.5    6  265      17.0     23.0  4451.0
# 3        79978              3.2    6  290      17.0     24.0  3153.0
#
#    Wheel Base    Len  Width
# 0       115.0  197.0   72.0
# 1       115.0  197.0   72.0
# 2       106.0  189.0   77.0
# 3       100.0  174.0   71.0
#    id  age  salary  height  family_size location     sex  \
# 0   1   18   32354     151            4    urban    male
# 1   2   57   32471     181            3    rural  female
# 2   3   21   90452     151            1    rural    male
# 3   4   40   56945     163            1    urban  female
#
#                            car
# 0       Toyota Celica GT-S 2dr
# 1      Ford Crown Victoria 4dr
# 2  BMW Z4 convertible 2.5i 2dr
# 3                   Volvo XC70

# %% [markdown]
# ### Utility functions and classes

# %%
def cols_to_snake(df):
    ''' function to make all column headers snake case
    
    Input: pd dataframe
    Outputs: pd dataframe with clean headers
    
    '''
        
    df.columns = df.columns.astype("str")
    df.columns = df.columns.str.lower()
    df.columns = df.columns.map(lambda x : x.replace("-", "_").replace(" ", "_").replace("/", ""))
    return df

# %%
cars = cols_to_snake(cars)
people = cols_to_snake(people)

# %%
display(cars[:4])
display(people[:4])
# Out:
#                     vehicle_name  smallsporty_compactlarge_sedan  sports_car  \
# 0               Acura 3.5 RL 4dr                               1           0
# 1  Acura 3.5 RL w/Navigation 4dr                               1           0
# 2                      Acura MDX                               0           0
# 3   Acura NSX coupe 2dr manual S                               0           1
#
#    suv  wagon  minivan  pickup  awd  rwd  retail_price  dealer_cost  \
# 0    0      0        0       0    0    0         43755        39014
# 1    0      0        0       0    0    0         46100        41100
# 2    1      0        0       0    1    0         36945        33337
# 3    0      0        0       0    0    1         89765        79978
#
#    engine_size_(l)  cyl   hp  city_mpg  hwy_mpg  weight  wheel_base    len  \
# 0              3.5    6  225      18.0     24.0  3880.0       115.0  197.0
# 1              3.5    6  225      18.0     24.0  3893.0       115.0  197.0
# 2              3.5    6  265      17.0     23.0  4451.0       106.0  189.0
# 3              3.2    6  290      17.0     24.0  3153.0       100.0  174.0
#
#    width
# 0   72.0
# 1   72.0
# 2   77.0
# 3   71.0
#    id  age  salary  height  family_size location     sex  \
# 0   1   18   32354     151            4    urban    male
# 1   2   57   32471     181            3    rural  female
# 2   3   21   90452     151            1    rural    male
# 3   4   40   56945     163            1    urban  female
#
#                            car
# 0       Toyota Celica GT-S 2dr
# 1      Ford Crown Victoria 4dr
# 2  BMW Z4 convertible 2.5i 2dr
# 3                   Volvo XC70

# %%
people.dtypes # all datatypes are ok
# Out:
# id              int64
# age             int64
# salary          int64
# height          int64
# family_size     int64
# location       object
# sex            object
# car            object
# dtype: object

# %%
cars.dtypes
# Out:
# vehicle_name                       object
# smallsporty_compactlarge_sedan      int64
# sports_car                          int64
# suv                                 int64
# wagon                               int64
# minivan                             int64
# pickup                              int64
# awd                                 int64
# rwd                                 int64
# retail_price                        int64
# dealer_cost                         int64
# engine_size_(l)                   float64
# cyl                                 int64
# hp                                  int64
# city_mpg                          float64
# hwy_mpg                           float64
# weight                            float64
# wheel_base                        float64
# len                               float64
# width                             float64
# dtype: object

# %%
cars.to_parquet('1-cars.parquet')
people.to_parquet('1-people.parquet')
